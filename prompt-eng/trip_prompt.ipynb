# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')

client = OpenAI(api_key=openai_api_key)

# %%
def get_response(prompt):
    response =client.chat.completions.create(model='gpt-4.1-mini', messages=[{"role": "user", "content": prompt}],max_tokens=150, temperature=0)
    return response.choices[0].message.content

# %%
prompt = """
I need to plan for my 2 week beach vacation.
step 1: Four potential locations.
step 2: Each location must have accommodation options, some activities.
steo 3: Evaluate pros and cons for each locations.
"""

response = get_response(prompt)
print(response)
# Out:
# Great! Let's start planning your 2-week beach vacation step-by-step.
#
# ### Step 1: Four Potential Beach Locations
# 1. **Maui, Hawaii**
# 2. **Cancun, Mexico**
# 3. **Bali, Indonesia**
# 4. **Amalfi Coast, Italy**
#
# ---
#
# ### Step 2: Accommodation Options & Activities for Each Location
#
# #### 1. Maui, Hawaii
# - **Accommodation Options:**
#   - Luxury resorts (e.g., Four Seasons Resort Maui)
#   - Beachfront condos and vacation rentals
#   - Budget hotels and hostels in Kihei or Lahaina
# - **Activities:**
#   - Snorkeling at Molokini Crater
#   - Road to Hana scenic drive
#   -
